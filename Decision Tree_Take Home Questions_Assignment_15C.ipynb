# %% [markdown]
# ### Q1. Perform Exploratory Data Analysis (EDA) tasks
#
# <br>a) Visualize the 10 random rows of the data set
# <br>b) Generate the description for numeric variables
# <br>c) Check the shape of the data set
# <br>d) Generate the correlation matrix
# <br>e) Generate a correlogram

# %%
# importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset
df = pd.read_csv('admission.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %% [markdown]
# a) Visualize the 10 random rows of the data set

# %%
df.sample(10)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 83           84        322          115                  5  4.0   4.5  9.36
# 104         105        326          112                  3  3.5   3.0  9.05
# 385         386        335          117                  5  5.0   5.0  9.82
# 295         296        317          100                  2  3.0   2.5  8.57
# 413         414        317          101                  3  3.0   2.0  7.94
# 460         461        319          105                  4  4.0   4.5  8.66
# 41           42        316          105                  2  2.5   2.5  8.20
# 40           41        308          110                  3  3.5   3.0  8.00
# 13           14        307          109                  3  4.0   3.0  8.00
# 431         432        320          112                  2  3.5   3.5  8.78
#
#      Research  Chance of Admit
# 83          1              0.92
# 104         1              0.74
# 385         1              0.96
# 295         0              0.68
# 413         1              0.49
# 460         1              0.77
# 41          1              0.49
# 40          1              0.46
# 13          1              0.62
# 431         1              0.73

# %% [markdown]
# b) Generate the description for numeric variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %% [markdown]
# c) Check the shape of the data set

# %%
df.shape
# Out:
# (500, 9)

# %% [markdown]
# d) Generate the correlation matrix

# %%
# make correlation matrix
matrix = df.corr()
 
# print correlation matrix
print("Correlation Matrix is : ")
print(matrix)
# Out:
# Correlation Matrix is :
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.103839    -0.141696          -0.067641
# GRE Score           -0.103839   1.000000     0.827200           0.635376
# TOEFL Score         -0.141696   0.827200     1.000000           0.649799
# University Rating   -0.067641   0.635376     0.649799           1.000000
# SOP                 -0.137352   0.613498     0.644410           0.728024
# LOR                 -0.003694   0.524679     0.541563           0.608651
# CGPA                -0.074289   0.825878     0.810574           0.705254
# Research            -0.005332   0.563398     0.467012           0.427047
# Chance of Admit      0.008505   0.810351     0.792228           0.690132
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.137352 -0.003694 -0.074289 -0.005332          0.008505
# GRE Score          0.613498  0.524679  0.825878  0.563398          0.810351
# TOEFL Score        0.644410  0.541563  0.810574  0.467012          0.792228
# University Rating  0.728024  0.608651  0.705254  0.427047          0.690132
# SOP                1.000000  0.663707  0.712154  0.408116          0.684137
# LOR                0.663707  1.000000  0.637469  0.372526          0.645365
# CGPA               0.712154  0.637469  1.000000  0.501311          0.882413
# Research           0.408116  0.372526  0.501311  1.000000          0.545871
# Chance of Admit    0.684137  0.645365  0.882413  0.545871          1.000000

# %% [markdown]
# e) Generate a correlogram

# %%
#Correlogram
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True, fmt = '.0%')
# Out:
# <Axes: >

# %%
#Second Approach
plt.figure(figsize=(20,20))
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
dataplot
# Out:
# <Axes: >

# %% [markdown]
# ### Q.2 Find out the minimum and maximum values for GRE score

# %%
df["GRE Score"].min()
# Out:
# 290

# %%
df["GRE Score"].max()
# Out:
# 340

# %%
plt.hist(df["GRE Score"])

plt.show()

# %% [markdown]
# Here minimum in 290 and maximum is 340

# %% [markdown]
# ### Q.3 Find out the percentage of universities for each university rating

# %%
total = df['University Rating'].value_counts().values.sum()
def fmt(x):
    return '{:.1f}%\n{:.0f}'.format(x, total*x/100)
plt.pie(df['University Rating'].value_counts().values, labels=df['University Rating'].value_counts().index, autopct=fmt)
# Out:
# ([<matplotlib.patches.Wedge at 0x19cee049750>,
#   <matplotlib.patches.Wedge at 0x19cee082250>,
#   <matplotlib.patches.Wedge at 0x19cee083c90>,
#   <matplotlib.patches.Wedge at 0x19cee0833d0>,
#   <matplotlib.patches.Wedge at 0x19cee993850>],
#  [Text(0.5776920901528353, 0.936093931704959, '3'),
#   Text(-1.0461621742897658, 0.3399186742226879, '2'),
#   Text(-0.4620942904114756, -0.9982328720138979, '4'),
#   Text(0.6958271640656856, -0.8519533776846627, '5'),
#   Text(1.074994933217536, -0.23320783339464807, '1')],
#  [Text(0.315104776447001, 0.5105966900208867, '32.4%\n162'),
#   Text(-0.5706339132489631, 0.18541018593964795, '25.2%\n126'),
#   Text(-0.2520514311335321, -0.544490657462126, '21.0%\n105'),
#   Text(0.3795420894903739, -0.46470184237345236, '14.6%\n73'),
#   Text(0.5863608726641104, -0.1272042727607171, '6.8%\n34')])

# %% [markdown]
# ### Q.4 Convert the target variable “Chance of Admit” to categorical having values 0 and 1,such that :
# <br>Students having the “Chance of Admit” value &gt; 0.80, are assigned value 1, and
# <br>Students having the “Chance of Admit” value &lt; 0.80, are assigned value 0
# <br>Where 0: Low chance of Admission and 1: High chance of admission

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
print(df.columns)
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df["Chance of Admit "]
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.loc[df['Chance of Admit '] <= 0.8, 'Chance of Admit '] = 0
df.loc[df['Chance of Admit '] > 0.8, 'Chance of Admit '] = 1

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1               1.0
# 1         1               0.0
# 2         1               0.0
# 3         1               0.0
# 4         0               0.0

# %% [markdown]
# ### Q.5 Build a Decision Tree classifier, to predict whether a student has a low or high chance of admission to a chosen university. Perform Hyperparameter Tuning to improve the accuracy of the model.

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
import category_encoders as ce
encoder = ce.OrdinalEncoder(cols=['Chance of Admit '])
df = encoder.fit_transform(df)
df.head(5)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\category_encoders\utils.py:28: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif pd.api.types.is_categorical_dtype(cols):
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\category_encoders\utils.py:50: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(dtype)
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\category_encoders\utils.py:50: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(dtype)
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\category_encoders\utils.py:50: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return pd.api.types.is_categorical_dtype(dtype)
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1                 1
# 1         1                 2
# 2         1                 2
# 3         1                 2
# 4         0                 2

# %%
x=df.drop(['Chance of Admit '],axis=1)

# %%
y=df['Chance of Admit '].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Decision Tree Classifier : {:.2f}%".format(dtc.score(x_test,y_test)*100))
# Out:
# Decision Tree Classifier : 91.33%

# %%
predictions=dtc.predict(x_test)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
conf_matrix=confusion_matrix(y_test,predictions)

# %%
print(conf_matrix)
# Out:
# [[ 29   6]
#  [  7 108]]

# %%
sns.heatmap(conf_matrix)
# Out:
# <Axes: >

# %% [markdown]
# # Decision Tree Classifier(Hyper parameter tuning)

# %%
dtc1=DecisionTreeClassifier(max_depth=4)

# %%
dtc1.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
print("Decision Tree Classifier with max depth 4 : {:.2f}%".format(dtc1.score(x_test,y_test)*100))
# Out:
# Decision Tree Classifier with max depth 4 : 92.67%

# %%
predictions2=dtc1.predict(x_test)

# %%
conf_matrix2=confusion_matrix(y_test,predictions2)

# %%
print(conf_matrix2)
# Out:
# [[ 30   5]
#  [  6 109]]

# %%
print(dtc1.score(x_train, y_train))
print(dtc1.score(x_test,y_test))
# Out:
# 0.9571428571428572
# 0.9266666666666666

# %% [markdown]
# # Post Prunning Technique

# %%
treemodel=DecisionTreeClassifier()

# %%
treemodel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.39752906976744184, 0.9375, 'x[6] <= 8.92\ngini = 0.425\nsamples = 350\nvalue = [107, 243]'),
#  Text(0.1569767441860465, 0.8125, 'x[1] <= 319.5\ngini = 0.082\nsamples = 232\nvalue = [10, 222]'),
#  Text(0.046511627906976744, 0.6875, 'x[6] <= 8.765\ngini = 0.021\nsamples = 189\nvalue = [2, 187]'),
#  Text(0.023255813953488372, 0.5625, 'gini = 0.0\nsamples = 181\nvalue = [0, 181]'),
#  Text(0.06976744186046512, 0.5625, 'x[6] <= 8.775\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.046511627906976744, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09302325581395349, 0.4375, 'x[1] <= 312.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.06976744186046512, 0.3125, 'x[7] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.046511627906976744, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09302325581395349, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11627906976744186, 0.3125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.26744186046511625, 0.6875, 'x[0] <= 334.0\ngini = 0.303\nsamples = 43\nvalue = [8, 35]'),
#  Text(0.16279069767441862, 0.5625, 'x[4] <= 2.25\ngini = 0.142\nsamples = 26\nvalue = [2, 24]'),
#  Text(0.13953488372093023, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18604651162790697, 0.4375, 'x[6] <= 8.845\ngini = 0.077\nsamples = 25\nvalue = [1, 24]'),
#  Text(0.16279069767441862, 0.3125, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(0.20930232558139536, 0.3125, 'x[1] <= 322.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.18604651162790697, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23255813953488372, 0.1875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.37209302325581395, 0.5625, 'x[3] <= 4.5\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.3488372093023256, 0.4375, 'x[0] <= 446.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.3023255813953488, 0.3125, 'x[5] <= 2.25\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.27906976744186046, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.32558139534883723, 0.1875, 'x[5] <= 4.75\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.3023255813953488, 0.0625, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.3488372093023256, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3953488372093023, 0.3125, 'x[2] <= 109.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.37209302325581395, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4186046511627907, 0.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3953488372093023, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6380813953488372, 0.8125, 'x[1] <= 318.5\ngini = 0.293\nsamples = 118\nvalue = [97, 21]'),
#  Text(0.5116279069767442, 0.6875, 'x[4] <= 4.75\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.4883720930232558, 0.5625, 'x[0] <= 95.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.46511627906976744, 0.4375, 'x[2] <= 108.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4418604651162791, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4883720930232558, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5116279069767442, 0.4375, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5348837209302325, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7645348837209303, 0.6875, 'x[6] <= 9.105\ngini = 0.212\nsamples = 108\nvalue = [95, 13]'),
#  Text(0.622093023255814, 0.5625, 'x[5] <= 3.25\ngini = 0.477\nsamples = 28\nvalue = [17, 11]'),
#  Text(0.5581395348837209, 0.4375, 'x[6] <= 9.09\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5348837209302325, 0.3125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.5813953488372093, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.686046511627907, 0.4375, 'x[2] <= 110.5\ngini = 0.363\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.627906976744186, 0.3125, 'x[4] <= 3.75\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.5813953488372093, 0.1875, 'x[0] <= 464.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5581395348837209, 0.0625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6046511627906976, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6744186046511628, 0.1875, 'x[1] <= 328.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6511627906976745, 0.0625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6976744186046512, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7441860465116279, 0.3125, 'x[0] <= 298.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.7209302325581395, 0.1875, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.7674418604651163, 0.1875, 'x[4] <= 4.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7441860465116279, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7906976744186046, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9069767441860465, 0.5625, 'x[0] <= 480.5\ngini = 0.049\nsamples = 80\nvalue = [78, 2]'),
#  Text(0.8604651162790697, 0.4375, 'x[0] <= 70.5\ngini = 0.026\nsamples = 77\nvalue = [76, 1]'),
#  Text(0.8372093023255814, 0.3125, 'x[0] <= 59.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.813953488372093, 0.1875, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.8604651162790697, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8837209302325582, 0.3125, 'gini = 0.0\nsamples = 65\nvalue = [65, 0]'),
#  Text(0.9534883720930233, 0.4375, 'x[1] <= 328.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9302325581395349, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9767441860465116, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
treemodel2=DecisionTreeClassifier(max_depth=4)

# %%
treemodel2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treemodel2,filled=True)
# Out:
# [Text(0.48, 0.9, 'x[6] <= 8.92\ngini = 0.425\nsamples = 350\nvalue = [107, 243]'),
#  Text(0.22, 0.7, 'x[1] <= 319.5\ngini = 0.082\nsamples = 232\nvalue = [10, 222]'),
#  Text(0.08, 0.5, 'x[6] <= 8.765\ngini = 0.021\nsamples = 189\nvalue = [2, 187]'),
#  Text(0.04, 0.3, 'gini = 0.0\nsamples = 181\nvalue = [0, 181]'),
#  Text(0.12, 0.3, 'x[6] <= 8.775\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.08, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16, 0.1, 'gini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.36, 0.5, 'x[0] <= 334.0\ngini = 0.303\nsamples = 43\nvalue = [8, 35]'),
#  Text(0.28, 0.3, 'x[4] <= 2.25\ngini = 0.142\nsamples = 26\nvalue = [2, 24]'),
#  Text(0.24, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.32, 0.1, 'gini = 0.077\nsamples = 25\nvalue = [1, 24]'),
#  Text(0.44, 0.3, 'x[0] <= 341.0\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.48, 0.1, 'gini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.74, 0.7, 'x[1] <= 318.5\ngini = 0.293\nsamples = 118\nvalue = [97, 21]'),
#  Text(0.64, 0.5, 'x[4] <= 4.75\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.6, 0.3, 'x[0] <= 95.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.56, 0.1, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.64, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.68, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.84, 0.5, 'x[6] <= 9.105\ngini = 0.212\nsamples = 108\nvalue = [95, 13]'),
#  Text(0.76, 0.3, 'x[5] <= 3.25\ngini = 0.477\nsamples = 28\nvalue = [17, 11]'),
#  Text(0.72, 0.1, 'gini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.8, 0.1, 'gini = 0.363\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.92, 0.3, 'x[7] <= 0.5\ngini = 0.049\nsamples = 80\nvalue = [78, 2]'),
#  Text(0.88, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.96, 0.1, 'gini = 0.026\nsamples = 77\nvalue = [76, 1]')]

# %% [markdown]
# # Pre Tuning

# %%
parameter={
    "criterion":["gini","entropy","log_loss"],
    "splitter":["best","random"],
    "max_depth":[1,2,3,4,5],
    "max_features":["auto","sqrt","log2"]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
treemodel6=DecisionTreeClassifier(max_depth=4)

# %%
cv=GridSearchCV(treemodel,param_grid=parameter,cv=5,scoring='accuracy')

# %%
cv.fit(x_train,y_train)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 150 fits failed out of a total of 450.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 150 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.83428571 0.82571429 0.84857143 0.78
#         nan        nan 0.87428571 0.78571429 0.88285714 0.85142857
#         nan        nan 0.90285714 0.84285714 0.89714286 0.87142857
#         nan        nan 0.89428571 0.84857143 0.89142857 0.84285714
#         nan        nan 0.89142857 0.90285714 0.89714286 0.90857143
#         nan        nan 0.77428571 0.78285714 0.85714286 0.74
#         nan        nan 0.84857143 0.78571429 0.86571429 0.83142857
#         nan        nan 0.86285714 0.81142857 0.90571429 0.89142857
#         nan        nan 0.9        0.86857143 0.9        0.88285714
#         nan        nan 0.89714286 0.84857143 0.91142857 0.88571429
#         nan        nan 0.85142857 0.73428571 0.86571429 0.71142857
#         nan        nan 0.9        0.84571429 0.88       0.85714286
#         nan        nan 0.87142857 0.84857143 0.88285714 0.85714286
#         nan        nan 0.86       0.84571429 0.89714286 0.89142857
#         nan        nan 0.89142857 0.87142857 0.90571429 0.88571429]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
cv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
y_test
# Out:
# array([2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2,
#        2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 2,
#        2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 1, 2, 2,
#        2, 1, 2, 2, 1, 2, 2, 2, 1, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 1, 2, 2,
#        2, 2, 2, 2, 2, 1, 2, 1, 2, 1, 2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 1,
#        1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1])

# %%
y_pred=cv.predict(x_test)

# %%
y_pred
# Out:
# array([2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2,
#        2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 2,
#        2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 1, 2, 1, 2, 2,
#        2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2,
#        2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 1, 2, 2,
#        2, 2, 2, 2, 2, 1, 2, 1, 1, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1])

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.9266666666666666

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.83      0.85      0.84        34
#            2       0.96      0.95      0.95       116
#
#     accuracy                           0.93       150
#    macro avg       0.89      0.90      0.90       150
# weighted avg       0.93      0.93      0.93       150

# %% [markdown]
# In original one its score was 91.33% after Hyperparameter tuning it has increased in some cases to 92% and further decreased to even 90%
